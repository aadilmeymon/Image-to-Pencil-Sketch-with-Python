# %% [markdown]
# ###### AUTHOR: Aadil Saleem

# %% [markdown]
# ### TASK 4 - Image to Pencil Sketch with Python

# %% [markdown]
# ##### Installing and importing libraries

# %%
pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Reading the image

# %%
image = cv2.imread("professor.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,6))
plt.imshow(image)
plt.axis('off')
plt.title('original image')
plt.show()

# %% [markdown]
# ##### Converting the original image into Gray Scale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,6))
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.title('gray image')
plt.show()

# %% [markdown]
# ##### Invert the grayscale image

# %%
inverted_image = 255 - gray_image
plt.figure(figsize=(8,6))
plt.imshow(inverted_image,cmap='gray')
plt.axis('off')
plt.title('inverted image')
plt.show()

# %% [markdown]
# ##### Blurring the inverted Image by using Guassian Function in OpenCV

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
plt.figure(figsize=(8,6))
plt.imshow(blurred_image,cmap='gray')
plt.axis('off')
plt.title('Blurred Inverted image')
plt.show()

# %% [markdown]
# #####  The final step: Inverting the blurred image, then converting the image into a pencil sketch

# %%
inverted_blurred = 255 - blurred_image
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.figure(figsize=(8,6))
plt.imshow(pencil_sketch,cmap='gray')
plt.axis('off')
plt.title('Pencil Sketch')
plt.show()

# %% [markdown]
# ##### Comparing Both Original and Pencil Sketch Image

# %%
image = cv2.imread("professor.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,6)).add_subplot(1, 2, 1)
plt.imshow(image)
plt.axis('off')
plt.title('original image')
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.figure(figsize=(8,6)).add_subplot(1, 2, 2)
plt.imshow(pencil_sketch,cmap='gray')
plt.axis('off')
plt.title('Pencil Sketch')
plt.show()
